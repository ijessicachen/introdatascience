# %% [markdown]
# # Problem Set 2, Question 5
#
# The following stress-strain data was collected on an unknown material sample, plot it and identify the following:
#
# 1. proportional limit
# 2. yield strength
# 3. ultimate tensile strength
# 4. fracture strength
# 5. linear elastic region
# 6. uniform plastic deformation region
# 7. onset of necking
# 8. non-uniform plastic deformation region

# %%
import matplotlib.pyplot as plt 

strain = [0, 0.0025, 0.005, 0.008, 0.01, 0.013, 0.017, 
          0.02, 0.03, 0.04, 0.05, 0.062, 0.075, 0.08]
stress = [0, 375, 750, 1200, 1500, 1700, 1850, 2000, 
          2100, 2150, 2200, 2130, 1980, 1600]

# %%
plt.plot(strain, stress)
